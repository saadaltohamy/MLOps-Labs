# %%
from pathlib import Path
import os

import kagglehub
from kagglehub.config import set_kaggle_api_token

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.base import clone
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import (
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    RandomForestClassifier,
)
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import skore
import wandb
from optuna.integration import WeightsAndBiasesCallback
from dotenv import load_dotenv
load_dotenv()

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /mnt/d/Programming/ITI/MLOps/Labs/mlops-lab0/.venv/lib/python3.12/site-packages/optuna/integration/wandb.py:5
#       4 try:
# ----> 5     from optuna_integration.wandb import WeightsAndBiasesCallback
#       6 except ModuleNotFoundError:
#
# ModuleNotFoundError: No module named 'optuna_integration'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File /mnt/d/Programming/ITI/MLOps/Labs/mlops-lab0/.venv/lib/python3.12/site-packages/optuna/integration/__init__.py:132, in _IntegrationModule._get_module(self, module_name)
#     131 try:
# --> 132     return importlib.import_module("." + module_name, self.__name__)
#     133 except ModuleNotFoundError:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File /mnt/d/Programming/ITI/MLOps/Labs/mlops-lab0/.venv/lib/python3.12/site-packages/optuna/integration/wandb.py:7
#       6 except ModuleNotFoundError:
# ----> 7     raise ModuleNotFoundError(_INTEGRATION_IMPORT_ERROR_TEMPLATE.format("wandb"))
#      10 __all__ = ["WeightsAndBiasesCallback"]
#
# ModuleNotFoundError:
# Could not find `optuna-integration` for `wandb`.
# Please run `pip install optuna-integration[wandb]`.
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 26
#      22 from sklearn.pipeline import Pipeline
#      23 from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
#      24 import skore
#      25 import wandb
# ---> 26 from optuna.integration import WeightsAndBiasesCallback
#      27 from dotenv import load_dotenv
#      28 load_dotenv()
#      29
#
# File /mnt/d/Programming/ITI/MLOps/Labs/mlops-lab0/.venv/lib/python3.12/site-packages/optuna/integration/__init__.py:120, in _IntegrationModule.__getattr__(self, name)
#     118     value = self._get_module(name)
#     119 elif name in self._class_to_module.keys():
# --> 120     module = self._get_module(self._class_to_module[name])
#     121     value = getattr(module, name)
#     122 else:
#
# File /mnt/d/Programming/ITI/MLOps/Labs/mlops-lab0/.venv/lib/python3.12/site-packages/optuna/integration/__init__.py:134, in _IntegrationModule._get_module(self, module_name)
#     132     return importlib.import_module("." + module_name, self.__name__)
#     133 except ModuleNotFoundError:
# --> 134     raise ModuleNotFoundError(_INTEGRATION_IMPORT_ERROR_TEMPLATE.format(module_name))
#
# ModuleNotFoundError:
# Could not find `optuna-integration` for `wandb`.
# Please run `pip install optuna-integration[wandb]`.

# %%
print(5)
# Out:
# 5
